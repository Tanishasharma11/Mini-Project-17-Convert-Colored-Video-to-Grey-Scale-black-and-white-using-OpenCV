# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanishasharma11/Mini-Project-17-Convert-Colored-Video-to-Grey-Scale-black-and-white-using-OpenCV/blob/main/Video_to_grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the module
import cv2

# %%
import os
from google.colab.patches import cv2_imshow

# %%
# reading the video
source = cv2.VideoCapture('/content/sample-5s.mp4')

# %%
import os

# Specify the directory name
directory_name = 'sample'

# Create the directory
os.mkdir(directory_name)

# Verify that the directory has been created
if os.path.isdir(directory_name):
    print('Directory created successfully.')
else:
    print('Failed to create the directory.')
# Out:
# Directory created successfully.

# %%
# running the loop
count=0
success=1
while success:

	# extracting the frames
	success, img = source.read()

	print(success)
	if success==False:
		break
	# converting to gray-scale
	gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

	# displaying the video
	cv2_imshow( gray)

	# Saves the frames with frame-count
	cv2.imwrite('/content/sample/frame%d.jpg' % count,gray)
	count+=1
	os.chdir('/content/sample')
	path='/content/sample'
	# exiting the loop
	key = cv2.waitKey(1)
	if key == ord("q"):
		break

# closing the window
cv2.destroyAllWindows()
# Out:
# True
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F1CB871F640>

# %%
os.chdir('/content/sample')
path='/content/sample'
video_name='grayvideo.mp4'
os.chdir("/content/sample")
images = [img for img in os.listdir(path)
              if img.endswith(".jpg") or
                 img.endswith(".jpeg") or
                 img.endswith("png")]
frame = cv2.imread(os.path.join(path, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, 0, 1, (width, height))
for image in images:
   video.write(cv2.imread(os.path.join(path, image)))
video.release()
